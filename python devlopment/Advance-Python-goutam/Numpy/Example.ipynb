# %% [markdown]
# #  welcome to  numpy

# %%
import sklearn

# %%
import numpy as np

# %%
print("Hello World")
# Out:
# Hello World

# %%
i
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 i
#
# NameError: name 'i' is not defined

# %%
i=45

# %%
print(i)
# Out:
# 45
